# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_train = pd.read_csv("au_train.csv")
df_test = pd.read_csv("au_test.csv")
df_train.replace(regex={'\?':'Other'},inplace=True)
df_test.replace(regex={'\?':'Other'},inplace=True)


df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  class           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# ## Plots of Age category for both train and test data set

# %%
sns.histplot(y=df_train['age'])

# This plot says the population is young, but I believe that this needs to have a weight to it, I believe that the fnlwgt represents that.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='age'>

# %%
sns.histplot(y=df_test['age'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='age'>

# %% [markdown]
# ## Plots of Education-num for both train and test data set

# %%
sns.histplot(y=df_train['workclass'])

# The ? is here too, and there is no Other category, therefore this will be promoted to other. 
# It appears that the ? only appears in not numerica data, so it is safe to assume that ? can be turned into other.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='workclass'>

# %%
sns.histplot(y=df_test['workclass'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='workclass'>

# %% [markdown]
# ## Plots of fnlwgt category for both train and test data set

# %%
sns.histplot(y=df_train['fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='fnlwgt'>

# %%
sns.histplot(y=df_test['fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='fnlwgt'>

# %%
## Plots of education category for both train and test data set

# %%
sns.histplot(y=df_train['education'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='education'>

# %%
sns.histplot(y=df_test['education'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='education'>

# %% [markdown]
# ## Plots of education-num category for both train and test data set

# %%
sns.histplot(y=df_train['education-num'])
# These numbers look ok, but I would expect most had 12 or 13 years of education. 
# I am assuming that k - 12
# Out:
# <AxesSubplot:xlabel='Count', ylabel='education-num'>

# %%
sns.histplot(y=df_test['education-num'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='education-num'>

# %% [markdown]
# ## Plots of marital-status category for both train and test data set

# %%
sns.histplot(y=df_train['marital-status'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='marital-status'>

# %%
sns.histplot(y=df_test['marital-status'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='marital-status'>

# %% [markdown]
# ## Plots of occupation category for both train and test data set

# %%
sns.histplot(y=df_train['occupation'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='occupation'>

# %%
sns.histplot(y=df_test['occupation'])

# There is a ? here so I will call this an Other. No reason to throw out this data. Since it seems that other is lacking in the data set.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='occupation'>

# %% [markdown]
# ## Plots of relationship category for both train and test data set

# %%
sns.histplot(y=df_train['relationship'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='relationship'>

# %%
sns.histplot(y=df_test['relationship'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='relationship'>

# %% [markdown]
# ## Plots of race category for both train and test data set

# %%
sns.histplot(y=df_train['race'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='race'>

# %%
sns.histplot(y=df_test['race'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='race'>

# %% [markdown]
# ## Plots of sex category for both train and test data set

# %%
# sns.histplot(y=df_train['sex'])
# sns.histplot(y=df_train['sex'],stat='probability',weights=df_train['fnlwgt'])
sns.histplot(y=df_train['sex'],stat='probability')

# Right from the start this does not look right. 
# I am assuming this is the census data for the US and it does not represent the population at least in terms of sex
# If this data was not randomly selected, but from a heavily male population town then this makes sense.
# I am going to assume that it was meant to represent the us population, but the us sex population is 50/50 but leans toward more females.
# Out:
# <AxesSubplot:xlabel='Probability', ylabel='sex'>

# %%
sns.histplot(y=df_test['sex'])
# sns.histplot(y=df_test['sex'],stat='probability',weights=df_test['fnlwgt'])
# sns.histplot(y=df_test['sex'],stat='probability')
# This test data set seems to be about half the size of the training data set. 
# But it seems that the ratio of female to male is similar.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='sex'>

# %% [markdown]
# ## Plots of capital-gain category for both train and test data set

# %%
sns.histplot(y=df_train['capital-gain'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='capital-gain'>

# %%
sns.histplot(y=df_test['capital-gain'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='capital-gain'>

# %% [markdown]
# ## Plots of capital-loss category for both train and test data set

# %%
sns.histplot(y=df_train['capital-loss'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='capital-loss'>

# %%
sns.histplot(y=df_test['capital-loss'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='capital-loss'>

# %%
sns.histplot(y=df_train['hours-per-week'],bins=10)

# Expected that 40 hour week was the most common and it is.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='hours-per-week'>

# %%
sns.histplot(y=df_test['hours-per-week'],bins=10)
# Before specifying the binning it seemed like the data didn not match well.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='hours-per-week'>

# %% [markdown]
# ## Plots of native-country category for both train and test data set

# %%
sns.histplot(y=df_train['native-country'])

# Need to spread out the axis it is too crowded. 
# Put in A-Z order.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='native-country'>

# %%
sns.histplot(y=df_test['native-country'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='native-country'>

# %% [markdown]
# ## Plots of class category for both train and test data set

# %%
sns.histplot(y=df_train['class'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='class'>

# %%
sns.histplot(y=df_test['class'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='class'>

# %% [markdown]
# # Additiona Plots to get a feel for the data and look for inconsistencies.

# %%
sns.histplot(y=df_train['age'],hue=df_train['class'],multiple='stack',bins=10)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='age'>

# %%
sns.histplot(y=df_train['workclass'],hue=df_train['class'],multiple='stack')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='workclass'>

# %%
# sns.histplot(y=df_train['sex'],hue=df_train['class'],multiple='stack',stat='probability')
sns.histplot(y=df_train['sex'],hue=df_train['class'],multiple='stack')
# Out:
# <AxesSubplot:xlabel='Probability', ylabel='sex'>

# %%
sns.histplot(y=df_test['sex'],hue=df_test['class'],multiple='stack')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='sex'>

# %%
sns.histplot(y=df_train['age'],hue=df_train['sex'],multiple='stack',bins=10)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='age'>

# %%
sns.histplot(y=df_train['education'],hue=df_train['sex'],multiple='stack')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='education'>

# %%
sns.histplot(y=df_train['race'],hue=df_train['sex'],multiple='stack')

# Something is not right with this, heavy skew toward white men.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='race'>

# %%
sns.histplot(y=df_train['marital-status'],hue=df_train['sex'],multiple='stack')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='marital-status'>

# %%
sns.histplot(y=df_train['workclass'],hue=df_train['sex'],multiple='stack')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='workclass'>

# %%
sns.histplot(y=df_test['workclass'],hue=df_test['sex'],multiple='stack')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='workclass'>

# %%
sns.histplot(y=df_test['occupation'],hue=df_test['sex'],multiple='stack')
# Heavily male dominated sample data.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='occupation'>

# %%
sns.histplot(y=df_train['occupation'],hue=df_train['sex'],multiple='stack')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='occupation'>

# %%
sns.histplot(y=df_train['hours-per-week'],hue=df_train['sex'],multiple='stack',bins=10)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='hours-per-week'>

# %%
sns.histplot(y=df_train['native-country'],hue=df_train['sex'],multiple='stack')
# Out:
# <AxesSubplot:xlabel='Count', ylabel='native-country'>

# %% [markdown]
# ## Thoughts
#
# Even if the train data is heavily skewed toward while male, the test data seems to have been doctored to match so any prediction we make shouldn't effect the outcome.
