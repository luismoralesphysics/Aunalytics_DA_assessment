# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df_train = pd.read_csv("au_train.csv")
df_test = pd.read_csv("au_test.csv")

df_train.info()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  class           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
sns.histplot(y=df_train['age'])

# This plot says the population is young, but I believe that this needs to have a weight to it, I believe that the fnlwgt represents that.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='age'>

# %%
sns.histplot(y=df_test['age'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='age'>

# %%
sns.histplot(y=df_train['education-num'])

# These numbers look ok, but I would expect most had 12 or 13 years of education. 
# I am assuming that k - 12
# Out:
# <AxesSubplot:xlabel='Count', ylabel='education-num'>

# %%
sns.histplot(y=df_test['education-num'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='education-num'>

# %%
sns.histplot(y=df_train['fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='fnlwgt'>

# %%
sns.histplot(y=df_test['fnlwgt'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='fnlwgt'>

# %%
sns.histplot(y=df_train['sex'])

# Right from the start this does not look right. 
# I am assuming this is the census data for the US and it does not represent the population at least in terms of sex
# If this data was not randomly selected, but from a heavily male population town then this makes sense.
# I am going to assume that it was meant to represent the us population, but the us sex population is 50/50 but leans toward more females.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='sex'>

# %%
sns.histplot(y=df_test['sex'])
# This test data set seems to be about half the size of the training data set. 
# But it seems that the ratio of female to male is similar.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='sex'>

# %%
sns.histplot(y=df_train['capital-gain'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='capital-gain'>

# %%
sns.histplot(y=df_test['capital-gain'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='capital-gain'>

# %%
sns.histplot(y=df_train['capital-loss'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='capital-loss'>

# %%
sns.histplot(y=df_test['capital-loss'])
# Out:
# <AxesSubplot:xlabel='Count', ylabel='capital-loss'>

# %%
sns.histplot(y=df_train['hours-per-week'],bins=10)

# Expected that 40 hour week was the most common and it is.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='hours-per-week'>

# %%
sns.histplot(y=df_test['hours-per-week'],bins=10)
# Before specifying the binning it seemed like the data didn not match well.
# Out:
# <AxesSubplot:xlabel='Count', ylabel='hours-per-week'>
